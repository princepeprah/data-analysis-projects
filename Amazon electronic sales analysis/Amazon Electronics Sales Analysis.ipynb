# %% [markdown]
# ### Importing the necesary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_csv(r"C:\Users\princ\Desktop\projects\data-analysis-projects\Amazon electronic sales analysis\electronics.csv")

# %% [markdown]
# ### Shows first ten rows

# %%
df.head(10)
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
# 5        0        5     2.0  1999-07-12     Female  Portable Audio & Video
# 6        0        6     5.0  1999-07-13     Female  Portable Audio & Video
# 7        0        7     2.0  1999-07-13     Female  Portable Audio & Video
# 8        0        8     4.0  1999-07-16     Female  Portable Audio & Video
# 9        0        9     5.0  1999-08-20     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# ...

# %% [markdown]
# ### Shows the sahpe of the dataset

# %%
df.shape
# Out:
# (1292954, 10)

# %% [markdown]
# ### Information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292954 entries, 0 to 1292953
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   item_id     1292954 non-null  int64
#  1   user_id     1292954 non-null  int64
#  2   rating      1292954 non-null  float64
#  3   timestamp   1292954 non-null  object
#  4   model_attr  1292954 non-null  object
#  5   category    1292954 non-null  object
#  6   brand       331120 non-null   object
#  7   year        1292954 non-null  int64
#  8   user_attr   174124 non-null   object
#  9   split       1292954 non-null  int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 98.6+ MB

# %% [markdown]
# ### Convertint datatype of timestamp into datetime

# %%
from datetime import datetime

df['timestamp']=pd.to_datetime(df['timestamp'])

# %% [markdown]
# ### Gives summary statistcis about the dataset.

# %%
df.describe()
# Out:
#             item_id       user_id        rating  \
# count  1.292954e+06  1.292954e+06  1.292954e+06
# mean   4.183588e+03  5.605127e+05  4.051482e+00
# min    0.000000e+00  0.000000e+00  1.000000e+00
# 25%    2.018000e+03  2.697482e+05  4.000000e+00
# 50%    3.930000e+03  5.518920e+05  5.000000e+00
# 75%    6.289000e+03  8.474858e+05  5.000000e+00
# max    9.559000e+03  1.157632e+06  5.000000e+00
# std    2.525346e+03  3.342374e+05  1.379732e+00
#
#                            timestamp          year         split
# count                        1292954  1.292954e+06  1.292954e+06
# mean   2015-06-18 11:30:34.851355904  2.012938e+03  1.747587e-01
# min              1999-06-13 00:00:00  1.999000e+03  0.000000e+00
# 25%              2014-09-06 00:00:00  2.012000e+03  0.000000e+00
# 50%              2015-10-19 00:00:00  2.014000e+03  0.000000e+00
# 75%              2016-10-19 00:00:00  2.015000e+03  0.000000e+00
# max              2018-10-01 00:00:00  2.018000e+03  2.000000e+00
# ...

# %% [markdown]
#  The summary statistics shows the insight below:
#
#  1. ~ The mean rating is 4.
#
#  2. The minimum rating is 1.
#
#  3. The maximum rating is 5.
#
#  4. The standard deviation of the ratings is 1.4.
#
#  5. The 25th percentile of the ratings is 4.
#
#  6. The 50th percentile of the ratings is 5.
#
#  7. The 75th percentile of the ratings is 5.

# %% [markdown]
# ### Checks for duplicates values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Checks for missing values

# %%
df.isnull().sum()
# Out:
# item_id             0
# user_id             0
# rating              0
# timestamp           0
# model_attr          0
# category            0
# brand          961834
# year                0
# user_attr     1118830
# split               0
# dtype: int64

# %% [markdown]
# ###
#
#
# Drops all null values

# %%
# df.dropna(inplace=True)
# df.isnull().sum()

# %%
df.head(10)
# Out:
#    item_id  user_id  rating  timestamp model_attr                category  \
# 0        0        0     5.0 1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0 1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0 1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0 1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0 1999-07-06     Female  Portable Audio & Video
# 5        0        5     2.0 1999-07-12     Female  Portable Audio & Video
# 6        0        6     5.0 1999-07-13     Female  Portable Audio & Video
# 7        0        7     2.0 1999-07-13     Female  Portable Audio & Video
# 8        0        8     4.0 1999-07-16     Female  Portable Audio & Video
# 9        0        9     5.0 1999-08-20     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# ...

# %% [markdown]
# ### How the ratings are distributed

# %%
df['rating'].value_counts()
# Out:
# rating
# 5.0    755755
# 4.0    214166
# 1.0    143755
# 3.0    100630
# 2.0     78648
# Name: count, dtype: int64

# %% [markdown]
# The highest number of ratings were 5 - with total number of 755755

# %%
df['year'] = pd.DatetimeIndex(df['timestamp']).year

df['year'].value_counts()
# Out:
# year
# 2015    320887
# 2016    302619
# 2017    192477
# 2014    180676
# 2013     99855
# 2018     80229
# 2012     38389
# 2011     23894
# 2010     16888
# 2009     12804
# 2008      9428
# 2007      6798
# 2006      2614
# 2005      2170
# 2004      1275
# 2003       833
# 2002       481
# 2001       403
# 2000       187
# 1999        47
# Name: count, dtype: int64

# %% [markdown]
# The highest number of sales was recorded in the year 2015

# %%
df['month'] = pd.DatetimeIndex(df['timestamp']).month

df['month'].value_counts()
# Out:
# month
# 1     140773
# 12    124597
# 3     116464
# 2     110546
# 8     109835
# 7     107612
# 4      99136
# 5      98207
# 9      97368
# 11     97015
# 6      96317
# 10     95084
# Name: count, dtype: int64

# %% [markdown]
# The highest number of sales was recorded in the month of January

# %% [markdown]
# ## Visualizations

# %%
# Ratings distribution 
sns.countplot(x='rating', data=df)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
#Sales by years

plt.figure(figsize=(10,5))
sns.countplot(x='year', data=df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
# Highest Sales by brands

plt.figure(figsize=(10,5))
sns.countplot(x='brand', data=df, order=df['brand'].value_counts().iloc[1:10].index)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %% [markdown]
# Logitech recorded the highest number of sales followed by Sony with Pyle and Etre Jeune recording the least

# %%
# Lowest sales by brands

plt.figure(figsize=(15,5))
sns.countplot(x='brand', data=df, order=df['brand'].value_counts().iloc[-10:].index)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %% [markdown]
# Koolertron recorded the lowest sales followed by Duragadget

# %%
# Highest sales in 2015 by brands

plt.figure(figsize=(12,6))
sns.countplot(x='brand', data=df[df['year'] == 2015], order=df['brand'].value_counts().iloc[1:10].index)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %% [markdown]
# Mpow recorded the highest number of sales in 2015

# %%
# Highest sales in 2016 by brands

plt.figure(figsize=(12,6))
sns.countplot(x='brand', data=df[df['year'] == 2016], order=df['brand'].value_counts().iloc[1:10].index)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %% [markdown]
# Logitech recorded the highest number of sales in 2016

# %%
# Highest sales in 2017 by brands - Logitech

plt.figure(figsize=(12,6))
sns.countplot(x='brand', data=df[df['year'] == 2017], order=df['brand'].value_counts().iloc[1:10].index)
# Out:
# <Axes: xlabel='brand', ylabel='count'>

# %%
# Month with the highest sales - January

sns.countplot(x='month', data=df)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
# Category with the highest sales - Computers & Accessories

plt.figure(figsize=(20,6))
sns.countplot(x='category', data=df[df['month'] == 1], order=df['category'].value_counts().iloc[1:10].index)
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
# Category with the least sales - Security & Surveillance

plt.figure(figsize=(20,6))
sns.countplot(x='category', data=df, order=df['category'].value_counts().iloc[-10:].index)
# Out:
# <Axes: xlabel='category', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
df.groupby('category')['rating'].count().sort_values(ascending=False).head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='rating'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# - The highest number of sales was recorded in the year 2015
# - The highest sales was recorded in the month of Jnauary
# - The brand logitech recorded the highest number of sales followed by sony.
# - The brand Koolertron recorded the lowest sales followed by Duragadget.
# - Category with the highest sales - Computers & Accessories
# - Category with the least sales - Security & Surveillance
